# %% [markdown]
# <a href="https://colab.research.google.com/github/nandith2007/2025AIAC/blob/main/B10_2278_ML_ASSIGNMENT3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Understanding and Loading the Dataset**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
x = df[['YearsExperience']]
print(x)
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y = df['Salary']
print(y)
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %% [markdown]
# # **Data Preprocessing using NumPy**

# %%
x = df[['YearsExperience']]
print(x)
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y = df['Salary']
print(y)
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
x = np.array(X)
y = np.array(y)

# %%
x = x.reshape(-1, 1)
y = y.reshape(-1)

# %%
x_norm = (x-x.min())/(x.max()-x.min())
y_norm = (y-y.min())/(y.max()-y.min())

# %% [markdown]
# # **Implementing Linear Regression Model from Scratch**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)

# %%
print("x_train shape:", x_train.shape)
# Out:
# x_train shape: (24, 1)

# %%
print("x_test shape:", x_test.shape)
# Out:
# x_test shape: (6, 1)

# %%
print("y_train shape:", y_train.shape)
# Out:
# y_train shape: (24,)

# %%
print("y_test shape:", y_test.shape)
# Out:
# y_test shape: (6,)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error(MSE):",mse)
# Out:
# Mean Squared Error(MSE): 49830096.855908394

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.scatterplot(x=y_test.flatten(),y=y_pred.flatten(),color='blue',label='Predicted Salaries')
sns.scatterplot(x=y_test.flatten(),y=y_test.flatten(),color='red',label='Actual Salaries(Ideal Fit)')
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],'k--',lw=2,label='Perfect Prediction Line')
plt.xlabel('Actual Salaries')
plt.ylabel('Predicted Salaries')
plt.title('Actual vs Predicted Salaries')
plt.legend()
plt.grid(True)
plt.show()

# %%
x_np=x.values.flatten()
y_np=y.values

x_mean=np.mean(x_np)
y_mean=np.mean(y_np)

numerator=np.sum((x_np-x_mean)*(y_np-y_mean))
denominator=np.sum((x_np-x_mean)**2)
m=numerator/denominator
c=y_mean-(m*x_mean)
print("Scratch slope:",m)
